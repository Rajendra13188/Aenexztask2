# %%
#1 to calculate the electricity bill
units=int(input("Enter electricity unitx: "))
if units<=100:
  bill=units*5
elif units<=200:
  bill=(100*5)+((units-100)*7)
else:
  bill=(100*5)+(100*7)+((units-200)*10)
print("Electricity Bill=$",bill)
# Out:
# Enter electricity unitx: 150
# Electricity Bill=$ 850

# %%
#2 customer purchases items from an online store
amount=float(input("Enter purchase amount: "))
if amount>=5000:
  discount=amount*0.20
elif amount>=2000:
  discount=amount*0.10
else:
  discount=0
final_amount=amount-discount
print("Original Amount = ₹", amount)
print("Discount Amount = ₹", discount)
print("Final Payable Amount = ₹", final_amount)
# Out:
# Enter purchase amount: 2000.5
# Original Amount = ₹ 2000.5
# Discount Amount = ₹ 200.05
# Final Payable Amount = ₹ 1800.45

# %%
#3 bank approves loans
age=int(input("Enter age: "))
salary=float(input("Enter monthly salary: "))
credit_score=int(input("Enter credit score: "))
if age>=21 and age<=60 and salary>=30000:
  if credit_score>=750:
    print("Loan Approved")
  elif credit_score>=650:
    print("Loan Approved with Guarantor")
  else:
    print("Loan Rejected")
else:
  print("Loan Rejected")
# Out:
# Enter age: 59
# Enter monthly salary: 100000
# Enter credit score: 700
# Loan Approved with Guarantor
